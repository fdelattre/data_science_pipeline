# %% [markdown]
# <a href="https://colab.research.google.com/github/fdelattre/data_science_pipeline/blob/master/toy_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/Colab Notebooks/Train.csv' #source : https://www.kaggle.com/prachi13/customer-analytics
data = pd.read_csv(filepath)
print(data.head())
print(data.tail())
# Out:
#    ID Warehouse_block  ... Weight_in_gms  Reached.on.Time_Y.N
# 0   1               D  ...          1233                    1
# 1   2               F  ...          3088                    1
# 2   3               A  ...          3374                    1
# 3   4               B  ...          1177                    1
# 4   5               C  ...          2484                    1
#
# [5 rows x 12 columns]
#           ID Warehouse_block  ... Weight_in_gms  Reached.on.Time_Y.N
# 10994  10995               A  ...          1538                    1
# 10995  10996               B  ...          1247                    0
# 10996  10997               C  ...          1155                    0
# 10997  10998               F  ...          1210                    0
# 10998  10999               D  ...          1639                    0
#
# [5 rows x 12 columns]

# %% [markdown]
# # Analyse exploratoire des données
#
# Nous commencerons par analyser graphiquement les différentes colonnes en essayant d'établir la corélation avec la variable Reached.on.Time

# %%
import seaborn as sns
sns.displot(data=data, x=var, hue = "Reached.on.Time_Y.N", col = data.columns)
